# %% [markdown]
# **Gabriel Machado, João Pedro Garcia, Matheus Lopes, Miguel Battendieri e Pedro Vendrametto**

# %%
# IMPORTANDO BIBLIOTECAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Abrindo, limpando e ajustando o Dataframe**

# %%
# ABRINDO O DATAFRAME
df = pd.read_excel('/content/drive/MyDrive/PUC-SP/default_of_credit_card_clients.xls')
pd.set_option('display.max_columns', None)
df
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9    X10    X11        X12        X13        X14        X15  \
# ...

# %%
# ALTERANDO A LEGENDA DAS COLUNAS
df.columns = df.iloc[0]
df = df[1:]
df
# Out:
# 0         ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  \
# 1          1     20000   2         2        1  24     2     2    -1    -1
# 2          2    120000   2         2        2  26    -1     2     0     0
# 3          3     90000   2         2        2  34     0     0     0     0
# 4          4     50000   2         2        1  37     0     0     0     0
# 5          5     50000   1         2        1  57    -1     0    -1     0
# ...      ...       ...  ..       ...      ...  ..   ...   ...   ...   ...
# 29996  29996    220000   1         3        1  39     0     0     0     0
# 29997  29997    150000   1         3        2  43    -1    -1    -1    -1
# 29998  29998     30000   1         2        2  37     4     3     2    -1
# 29999  29999     80000   1         3        1  41     1    -1     0     0
# 30000  30000     50000   1         2        1  46     0     0     0     0
#
# 0     PAY_5 PAY_6 BILL_AMT1 BILL_AMT2 BILL_AMT3 BILL_AMT4 BILL_AMT5 BILL_AMT6  \
# ...

# %%
df.info() # INFORMAÇÕES DO DATAFRAME
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  object
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  object
#  6   PAY_0                       30000 non-null  object
#  7   PAY_2                       30000 non-null  object
#  8   PAY_3                       30000 non-null  object
#  9   PAY_4                       30000 non-null  object
#  10  PAY_5                       30000 non-null  object
#  11  PAY_6                       30000 non-null  object
#  12  BILL_AMT1                   30000 non-null  object
# ...

# %%
# ALTERANDO AS COLUNAS DE OBJECT PARA FLOAT
for col in df:
    df[col] = df[col].astype(float)
# Out:
# <ipython-input-190-921663b3c01d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(float)
# <ipython-input-190-921663b3c01d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(float)
# <ipython-input-190-921663b3c01d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.info() # INFORMAÇÕES DO DATAFRAME
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  float64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  float64
#  3   EDUCATION                   30000 non-null  float64
#  4   MARRIAGE                    30000 non-null  float64
#  5   AGE                         30000 non-null  float64
#  6   PAY_0                       30000 non-null  float64
#  7   PAY_2                       30000 non-null  float64
#  8   PAY_3                       30000 non-null  float64
#  9   PAY_4                       30000 non-null  float64
#  10  PAY_5                       30000 non-null  float64
#  11  PAY_6                       30000 non-null  float64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
education_values = df['EDUCATION'].value_counts() # ANÁLISE DA COLUNA EDUCATION
print(education_values)
# Out:
# EDUCATION
# 2.0    14030
# 1.0    10585
# 3.0     4917
# 5.0      280
# 4.0      123
# 6.0       51
# 0.0       14
# Name: count, dtype: int64

# %%
df['EDUCATION'].replace(6, 5, inplace=True) # JUNTANDO 5 e 6 (QUE SÃO IGUAIS)
# Out:
# <ipython-input-193-121b61a805ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EDUCATION'].replace(6, 5, inplace=True) # JUNTANDO 5 e 6 (QUE SÃO IGUAIS)

# %%
education_values = df['EDUCATION'].value_counts() # ANÁLISE DA COLUNA EDUCATION
print(education_values)
# Out:
# EDUCATION
# 2.0    14030
# 1.0    10585
# 3.0     4917
# 5.0      331
# 4.0      123
# 0.0       14
# Name: count, dtype: int64

# %%
df = df[df['EDUCATION'] != 0] # EXCLUINDO LINHAS ONDE EDUCATION É IGUAL A 0
df
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 1          1.0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0
# 2          2.0   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0
# 3          3.0    90000.0  2.0        2.0       2.0  34.0    0.0    0.0
# 4          4.0    50000.0  2.0        2.0       1.0  37.0    0.0    0.0
# 5          5.0    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 29996  29996.0   220000.0  1.0        3.0       1.0  39.0    0.0    0.0
# 29997  29997.0   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0
# 29998  29998.0    30000.0  1.0        2.0       2.0  37.0    4.0    3.0
# 29999  29999.0    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0
# 30000  30000.0    50000.0  1.0        2.0       1.0  46.0    0.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
marriage_values = df['MARRIAGE'].value_counts() # ANÁLISE DA COLUNA 'MARRIAGE'
print(marriage_values)
# Out:
# MARRIAGE
# 2.0    15954
# 1.0    13655
# 3.0      323
# 0.0       54
# Name: count, dtype: int64

# %%
df = df[df['MARRIAGE'] != 0] # EXCLUINDO LINHAS ONDE MARRIAGE É IGUAL A 0
df
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 1          1.0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0
# 2          2.0   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0
# 3          3.0    90000.0  2.0        2.0       2.0  34.0    0.0    0.0
# 4          4.0    50000.0  2.0        2.0       1.0  37.0    0.0    0.0
# 5          5.0    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 29996  29996.0   220000.0  1.0        3.0       1.0  39.0    0.0    0.0
# 29997  29997.0   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0
# 29998  29998.0    30000.0  1.0        2.0       2.0  37.0    4.0    3.0
# 29999  29999.0    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0
# 30000  30000.0    50000.0  1.0        2.0       1.0  46.0    0.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
df.info() # INFORMAÇÕES DO DATAFRAME
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29932 entries, 1 to 30000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          29932 non-null  float64
#  1   LIMIT_BAL                   29932 non-null  float64
#  2   SEX                         29932 non-null  float64
#  3   EDUCATION                   29932 non-null  float64
#  4   MARRIAGE                    29932 non-null  float64
#  5   AGE                         29932 non-null  float64
#  6   PAY_0                       29932 non-null  float64
#  7   PAY_2                       29932 non-null  float64
#  8   PAY_3                       29932 non-null  float64
#  9   PAY_4                       29932 non-null  float64
#  10  PAY_5                       29932 non-null  float64
#  11  PAY_6                       29932 non-null  float64
#  12  BILL_AMT1                   29932 non-null  float64
# ...

# %% [markdown]
# # **Gráficos e estatísticas sobre o Dataframe**

# %%
df
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 1          1.0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0
# 2          2.0   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0
# 3          3.0    90000.0  2.0        2.0       2.0  34.0    0.0    0.0
# 4          4.0    50000.0  2.0        2.0       1.0  37.0    0.0    0.0
# 5          5.0    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 29996  29996.0   220000.0  1.0        3.0       1.0  39.0    0.0    0.0
# 29997  29997.0   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0
# 29998  29998.0    30000.0  1.0        2.0       2.0  37.0    4.0    3.0
# 29999  29999.0    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0
# 30000  30000.0    50000.0  1.0        2.0       1.0  46.0    0.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
age_counts = df.groupby('AGE')['default payment next month'].value_counts().unstack().fillna(0)

fig, ax = plt.subplots(figsize=(20, 6))

bar_width = 0.35

r1 = range(len(age_counts))
r2 = [x + bar_width for x in r1]

ax.bar(r1, age_counts[0], color='green', width=bar_width, label='Pago')

ax.bar(r2, age_counts[1], color='red', width=bar_width, label='Não pago')

ax.set_xlabel('Idade')
ax.set_ylabel('Contagem')
ax.set_title('Contagem de Default Payment por Idade')
ax.set_xticks([r + bar_width/2 for r in range(len(age_counts))])

ax.set_xticklabels(age_counts.index.astype(int))

plt.xticks(rotation=45)

ax.legend()

plt.show()

# %%
marriage_counts = df.groupby('MARRIAGE')['default payment next month'].value_counts().unstack().fillna(0)

fig, ax = plt.subplots(figsize=(10, 8))

bar_width = 0.35

r1 = np.arange(len(marriage_counts))
r2 = [x + bar_width for x in r1]

ax.bar(r1, marriage_counts[0], color='green', width=bar_width, label='Pago')

ax.bar(r2, marriage_counts[1], color='red', width=bar_width, label='Não pago')

ax.set_xlabel('ESTADO CIVIL')
ax.set_ylabel('CONTAGEM')
ax.set_title('Contagem de Default Payment por Estado Civil')
ax.set_xticks([r + bar_width/2 for r in range(len(marriage_counts))])
ax.set_xticklabels(['Casado', 'Solteiro', 'Outro'])
ax.legend()

plt.show()

# %%
education_counts = df.groupby('EDUCATION')['default payment next month'].value_counts().unstack().fillna(0)

fig, ax = plt.subplots(figsize=(10, 8))

bar_width = 0.35

r1 = np.arange(len(education_counts))
r2 = [x + bar_width for x in r1]

ax.bar(r1, education_counts[0], color='green', width=bar_width, label='Pago')

ax.bar(r2, education_counts[1], color='red', width=bar_width, label='Não pago')

ax.set_xlabel('ESCOLARIDADE')
ax.set_ylabel('CONTAGEM')
ax.set_title('Contagem de Default Payment por Escolaridade')
ax.set_xticks([r + bar_width/2 for r in range(len(education_counts))])
ax.set_xticklabels(['Pós-Graduação', 'Faculdade', 'Ensino Médio', 'Outros', 'Indefinido'])
ax.legend()

plt.show()

# %%
sex_counts = df.groupby('SEX')['default payment next month'].value_counts().unstack().fillna(0)

fig, ax = plt.subplots(figsize=(10, 8))

bar_width = 0.35

r1 = np.arange(len(sex_counts))
r2 = [x + bar_width for x in r1]

ax.bar(r1, sex_counts[0], color='green', width=bar_width, label='Pago')

ax.bar(r2, sex_counts[1], color='red', width=bar_width, label='Não pago')

ax.set_xlabel('SEXO')
ax.set_ylabel('CONTAGEM')
ax.set_title('Contagem de Default Payment por Sexo')
ax.set_xticks([r + bar_width/2 for r in range(len(sex_counts))])
ax.set_xticklabels(['Homem', 'Mulher'])
ax.legend()

plt.show()

# %% [markdown]
# # **Filtrando o Dataframe por colunas, definindo X e Y e aplicando a escala**

# %%
# COLUNAS A SEREM UTILIZADAS PARA PREVISÃO
df_columns = ['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6']

# %%
# SEPARANDO X E Y PARA PREVISÃO
X = df[df_columns]
Y = df['default payment next month']

# %%
# VISUALIZANDO O X
X
# Out:
# 0      LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 1        20000.0  2.0        2.0       1.0  24.0    2.0    2.0   -1.0   -1.0
# 2       120000.0  2.0        2.0       2.0  26.0   -1.0    2.0    0.0    0.0
# 3        90000.0  2.0        2.0       2.0  34.0    0.0    0.0    0.0    0.0
# 4        50000.0  2.0        2.0       1.0  37.0    0.0    0.0    0.0    0.0
# 5        50000.0  1.0        2.0       1.0  57.0   -1.0    0.0   -1.0    0.0
# ...          ...  ...        ...       ...   ...    ...    ...    ...    ...
# 29996   220000.0  1.0        3.0       1.0  39.0    0.0    0.0    0.0    0.0
# 29997   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0   -1.0   -1.0
# 29998    30000.0  1.0        2.0       2.0  37.0    4.0    3.0    2.0   -1.0
# 29999    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0    0.0    0.0
# 30000    50000.0  1.0        2.0       1.0  46.0    0.0    0.0    0.0    0.0
#
# ...

# %%
# VISUALIZANDO O Y
Y
# Out:
# 1        1.0
# 2        1.0
# 3        0.0
# 4        0.0
# 5        0.0
#         ...
# 29996    0.0
# 29997    0.0
# 29998    1.0
# 29999    1.0
# 30000    1.0
# Name: default payment next month, Length: 29932, dtype: float64

# %%
# PRINTANDO O NOME DOS ATRIBUTOS E CALCULANDO OS TAMANHOS DOS DATAFRAMES DE X E Y
print('Nomes dos Atributos: ', df_columns)
print('Tamanho de X: ', X.shape)
print('Tamanho de Y: ', Y.shape)
# Out:
# Nomes dos Atributos:  ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
# Tamanho de X:  (29932, 23)
# Tamanho de Y:  (29932,)

# %%
# APLICANDO A ESCALA A X
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# VISUALIZANDO O DATAFRAME DE X JÁ ATUALIZADO COM AS ESCALAS
X_scaled = pd.DataFrame(X_scaled, columns =X.columns)
X_scaled
# Out:
# 0      LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0     PAY_2  \
# 0      -1.136377  0.810441   0.191170 -1.070083 -1.245239  1.794683  1.782197
# 1      -0.366074  0.810441   0.191170  0.859419 -1.028293 -0.875707  1.782197
# 2      -0.597165  0.810441   0.191170  0.859419 -0.160510  0.014423  0.111311
# 3      -0.905286  0.810441   0.191170 -1.070083  0.164909  0.014423  0.111311
# 4      -0.905286 -1.233897   0.191170 -1.070083  2.334368 -0.875707  0.111311
# ...          ...       ...        ...       ...       ...       ...       ...
# 29927   0.404229 -1.233897   1.471565 -1.070083  0.381855  0.014423  0.111311
# 29928  -0.134983 -1.233897   1.471565  0.859419  0.815747 -0.875707 -0.724133
# 29929  -1.059347 -1.233897   0.191170  0.859419  0.164909  3.574942  2.617640
# 29930  -0.674195 -1.233897   1.471565 -1.070083  0.598801  0.904553 -0.724133
# 29931  -0.905286 -1.233897   0.191170 -1.070083  1.141166  0.014423  0.111311
#
# ...

# %% [markdown]
# # **Realizando as previsões e obtendo os primeiros resultados**

# %%
# CALCULANDO A QUANTIDADE DE DADOS DE TREINO E TESTE
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=123)

# %%
# PRINTANDO OS DADOS DE TREINO E TESTE
print('Tamanho de X_train: ', X_train.shape)
print('Tamanho de X_test: ', X_test.shape)
print('Tamanho de Y_train: ', Y_train.shape)
print('Tamanho de Y_test: ', Y_test.shape)
# Out:
# Tamanho de X_train:  (23945, 23)
# Tamanho de X_test:  (5987, 23)
# Tamanho de Y_train:  (23945,)
# Tamanho de Y_test:  (5987,)

# %%
# TREINANDO O MODELO DE REGRESSÃO LOGÍSTICA
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# CALCULANDO A RELEVÂNCIA DE CADA COLUNA
for feature, coef in zip(df_columns, clf.coef_[0].tolist()):
    print(f"{feature}: {round(coef, 10)}")

print(f"Constante: {round(clf.intercept_[0], 10)}")
# Out:
# LIMIT_BAL: -0.1086639565
# SEX: -0.0523222857
# EDUCATION: -0.0727772081
# MARRIAGE: -0.0768419166
# AGE: 0.074358651
# PAY_0: 0.6225314535
# PAY_2: 0.0960908397
# PAY_3: 0.0925631508
# PAY_4: 0.0113364758
# PAY_5: 0.0445907266
# PAY_6: 0.0179583748
# BILL_AMT1: -0.3834105496
# BILL_AMT2: 0.1129996688
# BILL_AMT3: 0.1531685651
# BILL_AMT4: -0.0728922913
# BILL_AMT5: 0.0361426674
# BILL_AMT6: 0.0528405784
# PAY_AMT1: -0.1935431184
# PAY_AMT2: -0.2058163149
# PAY_AMT3: -0.0660176841
# PAY_AMT4: -0.0612466231
# PAY_AMT5: -0.0189953997
# PAY_AMT6: -0.047812203
# Constante: -1.4503157742

# %%
# COMPARANDO OS DADOS DE TREINO AOS DADOS DE TESTE
from sklearn.metrics import accuracy_score

y_train_true = Y_train
y_train_pred = clf.predict(X_train)
y_test_true = Y_test
y_test_pred = clf.predict(X_test)

print(f"Acurácia de Treino: {round(accuracy_score(y_train_true, y_train_pred)*100, 2)}%")
print(f"Acurácia de Teste: {round(accuracy_score(y_test_true, y_test_pred)*100, 2)}%")
# Out:
# Acurácia de Treino: 80.77%
# Acurácia de Teste: 81.61%

# %%
# FAZENDO A MATRIZ DE CONFUSÃO DOS PRIMEIROS RESULTADOS

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_train_true, y_train_pred).plot()
ConfusionMatrixDisplay.from_predictions(y_test_true, y_test_pred).plot()

# %% [markdown]
# # **Realizando novas previsões com ajustes**

# %%
# APLICANDO THRESOLD AO TREINO
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_train, Y_train)

y_pred_prob1 = logistic_model.predict_proba(X_train)[:, 1]

threshold = 0.33

y_pred_adjusted_train = (y_pred_prob1 >= threshold).astype(int)

print("Matriz de Confusão - Regressão Logística (Threshold Ajustado):")
print(confusion_matrix(y_train_true, y_pred_adjusted_train))
print("Relatório de Classificação - Regressão Logística (Threshold Ajustado):")
print(classification_report(y_train_true, y_pred_adjusted_train))
# Out:
# Matriz de Confusão - Regressão Logística (Threshold Ajustado):
# [[17046  1584]
#  [ 3013  2302]]
# Relatório de Classificação - Regressão Logística (Threshold Ajustado):
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88     18630
#          1.0       0.59      0.43      0.50      5315
#
#     accuracy                           0.81     23945
#    macro avg       0.72      0.67      0.69     23945
# weighted avg       0.79      0.81      0.80     23945

# %%
# APLICANDO THRESOLD AO TESTE
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(X_test, Y_test)

y_pred_prob = logistic_model.predict_proba(X_test)[:, 1]

threshold = 0.33

y_pred_adjusted = (y_pred_prob >= threshold).astype(int)

print("Matriz de Confusão - Regressão Logística (Threshold Ajustado):")
print(confusion_matrix(y_test_true, y_pred_adjusted))
print("Relatório de Classificação - Regressão Logística (Threshold Ajustado):")
print(classification_report(y_test_true, y_pred_adjusted))
# Out:
# Matriz de Confusão - Regressão Logística (Threshold Ajustado):
# [[4266  405]
#  [ 692  624]]
# Relatório de Classificação - Regressão Logística (Threshold Ajustado):
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.91      0.89      4671
#          1.0       0.61      0.47      0.53      1316
#
#     accuracy                           0.82      5987
#    macro avg       0.73      0.69      0.71      5987
# weighted avg       0.80      0.82      0.81      5987

# %%
# MATRIZ DE CONFUSÃO DO TREINO

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_train_true, y_pred_adjusted_train).plot()

# %%
# MATRIZ DE CONFUSÃO DO TESTE

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test_true, y_pred_adjusted).plot()

# %%
print(f"Acurácia de Treino: {round(accuracy_score(y_train_true, y_pred_adjusted_train)*100, 2)}%")
print(f"Acurácia de Teste: {round(accuracy_score(y_test_true, y_pred_adjusted)*100, 2)}%")
# Out:
# Acurácia de Treino: 80.8%
# Acurácia de Teste: 81.68%

# %% [markdown]
# # **Realizando previsões usando Undersampling**

# %%
df
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 1          1.0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0
# 2          2.0   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0
# 3          3.0    90000.0  2.0        2.0       2.0  34.0    0.0    0.0
# 4          4.0    50000.0  2.0        2.0       1.0  37.0    0.0    0.0
# 5          5.0    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 29996  29996.0   220000.0  1.0        3.0       1.0  39.0    0.0    0.0
# 29997  29997.0   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0
# 29998  29998.0    30000.0  1.0        2.0       2.0  37.0    4.0    3.0
# 29999  29999.0    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0
# 30000  30000.0    50000.0  1.0        2.0       1.0  46.0    0.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
contagem = df['default payment next month'].value_counts().sort_index()
contagem
# Out:
# default payment next month
# 0.0    23301
# 1.0     6631
# Name: count, dtype: int64

# %%
contagem.argmin(), contagem.min()
# Out:
# (1, 6631)

# %%
classes = [0, 1]
dicionario = {i: df[ df['default payment next month'] == i] for i in classes}

# %%
for key in dicionario:
  dicionario[key] = dicionario[key].sample(contagem.min(), replace=False)

# %%
df2 = pd.concat([dicionario[i] for i in classes], ignore_index=True, sort=False)
df2
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 0       5098.0   280000.0  2.0        2.0       1.0  31.0    0.0    0.0
# 1      23994.0    20000.0  1.0        2.0       2.0  25.0   -1.0   -1.0
# 2      26197.0   310000.0  2.0        2.0       1.0  33.0    0.0    0.0
# 3        162.0    50000.0  1.0        2.0       2.0  27.0    2.0   -1.0
# 4       5904.0    50000.0  2.0        2.0       1.0  45.0    0.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 13257  14315.0    80000.0  1.0        2.0       1.0  60.0    2.0    2.0
# 13258  20389.0    20000.0  1.0        2.0       2.0  23.0    2.0    2.0
# 13259   4443.0   360000.0  2.0        1.0       1.0  27.0    1.0   -2.0
# 13260  10642.0   120000.0  2.0        3.0       2.0  40.0    0.0    0.0
# 13261  28385.0   180000.0  2.0        3.0       1.0  46.0   -1.0    2.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
df2['default payment next month'].value_counts()
# Out:
# default payment next month
# 0.0    6631
# 1.0    6631
# Name: count, dtype: int64

# %%
X_u = df2[df_columns]
Y_u = df2['default payment next month']

# %%
scaler = StandardScaler()
X_u_scaled = scaler.fit_transform(X_u)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_u_train, X_u_test, y_u_train, y_u_test = train_test_split(X_u_scaled, Y_u, test_size=0.2, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_u_train, y_u_train)
y_pred_train_u = clf.predict(X_u_train)
print(classification_report(y_u_train, y_pred_train_u))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.71      0.69      5310
#          1.0       0.69      0.64      0.67      5299
#
#     accuracy                           0.68     10609
#    macro avg       0.68      0.68      0.68     10609
# weighted avg       0.68      0.68      0.68     10609

# %%
ConfusionMatrixDisplay.from_predictions(y_u_train, y_pred_train_u).plot()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_u_train, X_u_test, y_u_train, y_u_test = train_test_split(X_u_scaled, Y_u, test_size=0.2, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_u_train, y_u_train)
y_pred_u = clf.predict(X_u_test)
print(classification_report(y_u_test, y_pred_u))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.70      0.67      1321
#          1.0       0.68      0.64      0.66      1332
#
#     accuracy                           0.67      2653
#    macro avg       0.67      0.67      0.67      2653
# weighted avg       0.67      0.67      0.66      2653

# %%
ConfusionMatrixDisplay.from_predictions(y_u_test, y_pred_u).plot()

# %%
from sklearn.metrics import accuracy_score

y_u_train_true = y_u_train
y_u_train_pred = clf.predict(X_u_train)
y_u_test_true = y_u_test
y_u_test_pred = clf.predict(X_u_test)

print(f"Acurácia de Treino: {round(accuracy_score(y_u_train_true, y_u_train_pred)*100, 2)}%")
print(f"Acurácia de Teste: {round(accuracy_score(y_u_test_true, y_u_test_pred)*100, 2)}%")
# Out:
# Acurácia de Treino: 67.69%
# Acurácia de Teste: 66.53%

# %% [markdown]
# # **Realizando previsões usando Oversampling**

# %%
df
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 1          1.0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0
# 2          2.0   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0
# 3          3.0    90000.0  2.0        2.0       2.0  34.0    0.0    0.0
# 4          4.0    50000.0  2.0        2.0       1.0  37.0    0.0    0.0
# 5          5.0    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 29996  29996.0   220000.0  1.0        3.0       1.0  39.0    0.0    0.0
# 29997  29997.0   150000.0  1.0        3.0       2.0  43.0   -1.0   -1.0
# 29998  29998.0    30000.0  1.0        2.0       2.0  37.0    4.0    3.0
# 29999  29999.0    80000.0  1.0        3.0       1.0  41.0    1.0   -1.0
# 30000  30000.0    50000.0  1.0        2.0       1.0  46.0    0.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
contagem_ = df['default payment next month'].value_counts().sort_index()
contagem_
# Out:
# default payment next month
# 0.0    23301
# 1.0     6631
# Name: count, dtype: int64

# %%
contagem_.argmax(), contagem_.max()
# Out:
# (0, 23301)

# %%
classes = [0, 1]
dicionario_ = {i: df[ df['default payment next month'] == i] for i in classes}

# %%
for key in dicionario_:
  dicionario_[key] = dicionario_[key].sample(contagem_.max(), replace=True)

# %%
df3 = pd.concat([dicionario_[i] for i in classes], ignore_index=True, sort=False)
df3
# Out:
# 0           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 0       6298.0   440000.0  2.0        2.0       2.0  27.0   -1.0    0.0
# 1      22926.0   200000.0  2.0        5.0       1.0  43.0    0.0    0.0
# 2      21744.0    20000.0  2.0        2.0       1.0  24.0    0.0    0.0
# 3       6819.0   400000.0  1.0        1.0       1.0  46.0    0.0    0.0
# 4       7817.0    10000.0  2.0        3.0       1.0  51.0    1.0    2.0
# ...        ...        ...  ...        ...       ...   ...    ...    ...
# 46597  20368.0    20000.0  1.0        2.0       2.0  23.0    1.0    2.0
# 46598  14162.0    50000.0  1.0        2.0       2.0  25.0   -1.0    3.0
# 46599   7537.0   300000.0  1.0        2.0       1.0  32.0   -1.0   -1.0
# 46600  23469.0    50000.0  2.0        2.0       1.0  39.0    1.0    2.0
# 46601  26741.0   200000.0  1.0        3.0       2.0  26.0    2.0    0.0
#
# 0      PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# ...

# %%
df3['default payment next month'].value_counts()
# Out:
# default payment next month
# 0.0    23301
# 1.0    23301
# Name: count, dtype: int64

# %%
X_o = df3[df_columns]
Y_o = df3['default payment next month']

# %%
scaler = StandardScaler()
X_o_scaled = scaler.fit_transform(X_o)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_o_train, X_o_test, y_o_train, y_o_test = train_test_split(X_o_scaled, Y_o, test_size=0.2, random_state=123)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_o_train, y_o_train)
y_pred_train_o = clf.predict(X_o_train)
print(classification_report(y_o_train, y_pred_train_o))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.72      0.69     18788
#          1.0       0.69      0.63      0.66     18493
#
#     accuracy                           0.67     37281
#    macro avg       0.67      0.67      0.67     37281
# weighted avg       0.67      0.67      0.67     37281

# %%
ConfusionMatrixDisplay.from_predictions(y_o_train, y_pred_train_o).plot()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_o_train, X_o_test, y_o_train, y_o_test = train_test_split(X_o_scaled, Y_o, test_size=0.2, random_state=123)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_o_train, y_o_train)
y_pred_o = clf.predict(X_o_test)
print(classification_report(y_o_test, y_pred_o))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.72      0.68      4513
#          1.0       0.70      0.63      0.66      4808
#
#     accuracy                           0.67      9321
#    macro avg       0.67      0.67      0.67      9321
# weighted avg       0.68      0.67      0.67      9321

# %%
ConfusionMatrixDisplay.from_predictions(y_o_test, y_pred_o).plot()

# %%
from sklearn.metrics import accuracy_score

y_o_train_true = y_o_train
y_o_train_pred = clf.predict(X_o_train)
y_o_test_true = y_o_test
y_o_test_pred = clf.predict(X_o_test)

print(f"Acurácia de Treino: {round(accuracy_score(y_o_train_true, y_o_train_pred)*100, 2)}%")
print(f"Acurácia de Teste: {round(accuracy_score(y_o_test_true, y_o_test_pred)*100, 2)}%")
# Out:
# Acurácia de Treino: 67.35%
# Acurácia de Teste: 67.17%
